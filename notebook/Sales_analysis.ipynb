# %%
import pandas as pd

# %%
sales.groupby("Product")["Revenue"].sum().sort_values(ascending=False)
# Out:
# Product
# Laptop     265000
# Desktop    135000
# Printer     79000
# Monitor     57000
# Name: Revenue, dtype: int64

# %%
sales.groupby("Region")["Profit"].sum().sort_values(ascending=False).to_csv("Profit_by_Region.csv")

# %%
sales.groupby("Product").apply(
    lambda x: (x["Profit"].sum()/x["Revenue"].sum())*100
               ).sort_values(ascending=False)
# Out:
# /tmp/ipykernel_139/2690983686.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sales.groupby("Product").apply(
# Product
# Desktop    31.851852
# Printer    29.746835
# Monitor    28.070175
# Laptop     26.037736
# dtype: float64

# %%
sales.groupby("Product")[["Revenue","Budget_Revenue"]].sum().sort_values(by="Revenue",ascending=False)
# Out:
#          Revenue  Budget_Revenue
# Product
# Laptop    265000          275000
# Desktop   135000          145000
# Printer    79000           88000
# Monitor    57000           61000

# %%
sales.groupby("Product")["Revenue"].sum().plot(kind="bar")
import matplotlib.pyplot as plt
plt.title("Revenue by Product")
plt.ylabel("Revenue")
plt.tight_layout()
plt.savefig("Revenue_product.png")
plt.show()

# %%
sales.groupby("Product")["Revenue"].sum().to_csv("Revenue_product.csv")

# %%
sales.groupby("Product")["Profit"].sum().sort_values(ascending=False).plot(kind='bar')
import matplotlib.pyplot as ply
ply.title("Profit by Product")
plt.ylabel("Profit")
plt.tight_layout()
plt.savefig("Profit by Product.png")
plt.show()

# %%
sales.groupby("Product").apply(
    lambda x: (x["Profit"].sum()/x["Revenue"].sum())*100,
    include_groups=False
).to_csv("Profit_Margin.csv")
